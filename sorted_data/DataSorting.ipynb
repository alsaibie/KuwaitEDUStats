# %%
import tabula
import numpy as np

# %%
#2018 Data
# df_unsorted_2018_STEM = tabula.read_pdf("../unsorted_data/2018/2018_STEM.pdf")
# tabula.convert_into("../unsorted_data/2018/2018_STEM.pdf", "2018/2018_STEM_raw.csv", pages='all', output_format="csv")
# tabula.convert_into("../unsorted_data/2018/2018_Humanities.pdf", "2018/2018_Humanities_raw.csv", pages ='all', output_format="csv")

# %%
df_unsorted_2018_STEM.tail(10)
# Out:
#        النسبة النجاح    علمي                                        المدرسة  \
# 15136   91.63   ناجح  العلمي               النجاة النموذجية الثانوية للبنات
# 15137   82.38   ناجح  العلمي               النجاة النموذجية الثانوية للبنات
# 15138   85.47   ناجح  العلمي               النجاة النموذجية الثانوية للبنات
# 15139   85.70   ناجح  العلمي  الفحيحيل النموذجية الثانوية - بنات - المشتركة
# 15140   95.93   ناجح  العلمي  الفحيحيل النموذجية الثانوية - بنات - المشتركة
# 15141   91.44   ناجح  العلمي  الفحيحيل النموذجية الثانوية - بنات - المشتركة
# 15142   96.94   ناجح  العلمي  الفحيحيل النموذجية الثانوية - بنات - المشتركة
# 15143   99.81   ناجح  العلمي  الفحيحيل النموذجية الثانوية - بنات - المشتركة
# 15144   94.86   ناجح  العلمي  الفحيحيل النموذجية الثانوية - بنات - المشتركة
# 15145   77.84   ناجح  العلمي                       مركز الرجاء الثانوي رجال
#
#       حكومي/خاص المنطقة التعليمية الجنس الجنسية  \
# 15136       خاص     التعليم الخاص  بنات   كويتي
# ...

# %%
df_unsorted_2017_STEM = tabula.read_pdf("../unsorted_data/2017/2017_STEM.pdf")
df_unsorted_2017_STEM.tail(10)
# Out:
#      76.44  العلمي      يوسف بن عيسى الثانوية للبنين  حكــومى  العاصمة  بنين  \
# 92   90.63  العلمي  عبدالله العتيبي الثانوية  للبنين  حكــومى  العاصمة  بنين
# 93   75.75  العلمي  عبدالله العتيبي الثانوية  للبنين  حكــومى  العاصمة  بنين
# 94   77.42  العلمي  عبدالله العتيبي الثانوية  للبنين  حكــومى  العاصمة  بنين
# 95   75.54  العلمي  عبدالله العتيبي الثانوية  للبنين  حكــومى  العاصمة  بنين
# 96   74.73  العلمي  عبدالله العتيبي الثانوية  للبنين  حكــومى  العاصمة  بنين
# 97   94.79  العلمي  عبدالله العتيبي الثانوية  للبنين  حكــومى  العاصمة  بنين
# 98   79.16  العلمي  عبدالله العتيبي الثانوية  للبنين  حكــومى  العاصمة  بنين
# 99   91.22  العلمي  عبدالله العتيبي الثانوية  للبنين  حكــومى  العاصمة  بنين
# 100  81.18  العلمي  عبدالله العتيبي الثانوية  للبنين  حكــومى  العاصمة  بنين
# 101  94.76  العلمي  عبدالله العتيبي الثانوية  للبنين  حكــومى  العاصمة  بنين
#
#      كويتي          ابراهيم جمال ابراهيم الراشد  30002
# 92   كويتي         عبد العزيز جابر جزاع المطيرى  30128
# ...

# %%
# 2017 STEM
# tabula.convert_into("../unsorted_data/2017/2017_Humanities.pdf", "2017/2017_Humanities_raw.csv", pages='all', output_format="csv", java_options='-Xmx8192m')
# tabula.convert_into("../unsorted_data/2017/2017_STEM.pdf", "2017/2017_STEM_raw.csv", pages='all', output_format="csv", java_options='-Xmx8192m')

# %%
# 2012
width = 750
height = 750
left = 28
top = 318
area_ = [top, left, top + height, left + width]
tabula.convert_into("../unsorted_data/2012/2012_STEM.pdf", "2012/2012_STEM_raw.csv", pages='all', output_format="csv")
